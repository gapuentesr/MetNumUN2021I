# %% [markdown]
# ![qc_notebook_logo_rev0.png](data:image/png;base64,...)
# ## [Boot Camp]: Buy and Hold / Equities

# %% [markdown]
# ##Métodos Numéricos
# ###Gustavo Alberto Puentes Romero

# %% [markdown]
# #Periodo: 2019/05 - 2021/05 [Dos años]

# %% [markdown]
# ##1). Apple

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 5, 1)
        self.SetEndDate(2021, 5, 1)

        self.aapl = self.AddEquity("AAPL", Resolution.Minute)
        self.aapl.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("AAPL", 100)
            self.Debug( str(self.Portfolio["AAPL"].AveragePrice))

# %% [markdown]
# ![AAPL.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##2). Google

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 5, 1)
        self.SetEndDate(2021, 5, 1)

        self.goog = self.AddEquity("GOOG", Resolution.Minute)
        self.goog.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("GOOG", 100)
            self.Debug( str(self.Portfolio["GOOG"].AveragePrice))

# %% [markdown]
# ![GOOG.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##3). Disney

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 5, 1)
        self.SetEndDate(2021, 5, 1)

        self.dis = self.AddEquity("DIS", Resolution.Minute)
        self.dis.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("DIS", 100)
            self.Debug( str(self.Portfolio["DIS"].AveragePrice))

# %% [markdown]
# ![DIS.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##4). Microsoft

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 5, 1)
        self.SetEndDate(2021, 5, 1)

        self.msft = self.AddEquity("MSFT", Resolution.Minute)
        self.msft.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("MSFT", 100)
            self.Debug( str(self.Portfolio["MSFT"].AveragePrice))

# %% [markdown]
# ![MSFT.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##5). Tesla

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 5, 1)
        self.SetEndDate(2021, 5, 1)

        self.tsla = self.AddEquity("TSLA", Resolution.Minute)
        self.tsla.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("TSLA", 100)
            self.Debug( str(self.Portfolio["TSLA"].AveragePrice))

# %% [markdown]
# ![TSLA.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Periodo: 2020/11 - 2021/05 [Seis meses]

# %% [markdown]
# ##1). Apple

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2020, 11, 1)
        self.SetEndDate(2021, 5, 1)

        self.aapl = self.AddEquity("AAPL", Resolution.Minute)
        self.aapl.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("AAPL", 100)
            self.Debug( str(self.Portfolio["AAPL"].AveragePrice))

# %% [markdown]
# ![AAPL.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##2). Google

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2020, 11, 1)
        self.SetEndDate(2021, 5, 1)

        self.goog = self.AddEquity("GOOG", Resolution.Minute)
        self.goog.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("GOOG", 100)
            self.Debug( str(self.Portfolio["GOOG"].AveragePrice))

# %% [markdown]
# ![GOOG.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##3). Disney

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2020, 11, 1)
        self.SetEndDate(2021, 5, 1)

        self.dis = self.AddEquity("DIS", Resolution.Minute)
        self.dis.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("DIS", 100)
            self.Debug( str(self.Portfolio["DIS"].AveragePrice))

# %% [markdown]
# ![DIS.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##4). Microsoft

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2020, 11, 1)
        self.SetEndDate(2021, 5, 1)

        self.msft = self.AddEquity("MSFT", Resolution.Minute)
        self.msft.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("MSFT", 100)
            self.Debug( str(self.Portfolio["MSFT"].AveragePrice))

# %% [markdown]
# ![MSFT.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##5). Tesla

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2020, 11, 1)
        self.SetEndDate(2021, 5, 1)

        self.tsla = self.AddEquity("TSLA", Resolution.Minute)
        self.tsla.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        if not self.Portfolio.Invested:
            self.MarketOrder("TSLA", 100)
            self.Debug( str(self.Portfolio["TSLA"].AveragePrice))

# %% [markdown]
# ![TSLA.jpg](data:image/jpeg;base64,...)
