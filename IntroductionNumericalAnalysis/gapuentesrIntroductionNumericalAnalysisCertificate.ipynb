# %% [markdown]
# #Certificado de Coursera en LinkedIn

# %% [markdown]
# ![Gustavo Puentes I LinkedIn.png](data:image/png;base64,...)

# %% [markdown]
# ## Link del certificado
#
# https://coursera.org/share/c7ab3f3f938350067edc3922c2b5e121
